# %% [markdown]
# <a href="https://colab.research.google.com/github/Pimmiiiu/DW/blob/master/text2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df_train = pd.read_csv('https://raw.githubusercontent.com/plenoi/CMU_DataScience/master/train.txt',sep='|',header=None)

# %%
dictionary = pd.read_csv('https://raw.githubusercontent.com/plenoi/CMU_DataScience/master/mydict.csv', header= None)

# %%
def isThai(chr):
    cVal = ord(chr)
    if(cVal >= 3584 and cVal <= 3711):
        return True
    return False
    
def tokenize(string, length):
    string = ''.join(list(filter(isThai, string)))
    string = string.replace(' ','')
    result = dict() 
    for word in dictionary[0]:
        if len(word) > length:
            s = 0
            while (1):
                s = string.find(word, s)
                if (s == -1):
                    break
                else:
                    s = s + 1
                    result[s] = word
            string = string.replace(word,'฿'*len(word))  
    return [value for (key, value) in sorted(result.items())]

# %%
train_clean = []
for i in range(0,len(df_train)):
    train_clean.append(tokenize(df_train.iloc[i][0],3))

# %%
train_clean[0]
# Out:
# ['ร้าน',
#  'ก๋วยเตี๋ยว',
#  'อยู่',
#  'ฝั่ง',
#  'ตรงข้าม',
#  'วิทยาเขต',
#  'องครักษ์',
#  'นครนายก',
#  'สามารถ',
#  'หน้าร้าน',
#  'ประมาณ',
#  'ร้าน',
#  'เรีย',
#  'โอเพ่น',
#  'แอร์',
#  'ห้อง',
#  'ติดแอร์',
#  'การบริการ',
#  'มาตรฐาน',
#  'อาหาร',
#  'เน้น',
#  'เป็น',
#  'ก๋วยเตี๋ยว',
#  'ลูกชิ้น',
#  'อาหารตา',
#  'สั่ง',
#  'สั่ง',
#  'เส้นใหญ่',
#  'เพิ่ม',
#  'เกี๊ยว',
#  'สั่ง',
#  'น้ำจิ้ม',
#  'เต้าเจี้ยว',
#  'ด้วย',
#  'รสชาติ',
#  'กลมกล่อม',
#  'คล้ายๆ',
#  'ข้าวต้ม',
#  'เนื้อ',
#  'เกี๊ยว',
#  'เพิ่ม',
#  'ได้ตัว',
#  'โดยรวม',
#  'โอเค',
#  'ส่วนตัว',
#  'วุ้นเส้น',
#  'เย็นตาโฟ',
#  'ทะเล',
#  'วุ้นเส้น',
#  'เยอะ',
#  'เครื่อง',
#  'ทะเล',
#  'ปลาหมึก',
#  'กุ้ง',
#  'แมงกะพรุน',
#  'ลูกชิ้น',
#  'รสชาติ',
#  'เย็นตาโฟ',
#  'อร่อย',
#  'กลมกล่อม',
#  'ไม่ต้อง',
#  'ปรุง',
#  'เพิ่ม',
#  'เส้น',
#  'เส้น',
#  'หนึบ',
#  'พร้อม',
#  'ลูกชิ้น',
#  'รสชาติ',
#  'อร่อย',
#  'น้ำแข็งเปล่า',
#  'แก้ว',
#  'น้ำเปล่า',
#  'โดยรวม',
#  'โอเค']

# %%
train_clean_join = []
for i in range(0,len(train_clean)):
    train_clean_join.append(' '.join(train_clean[i]))
train_clean_join[0]
# Out:
# 'ร้าน ก๋วยเตี๋ยว อยู่ ฝั่ง ตรงข้าม วิทยาเขต องครักษ์ นครนายก สามารถ หน้าร้าน ประมาณ ร้าน เรีย โอเพ่น แอร์ ห้อง ติดแอร์ การบริการ มาตรฐาน อาหาร เน้น เป็น ก๋วยเตี๋ยว ลูกชิ้น อาหารตา สั่ง สั่ง เส้นใหญ่ เพิ่ม เกี๊ยว สั่ง น้ำจิ้ม เต้าเจี้ยว ด้วย รสชาติ กลมกล่อม คล้ายๆ ข้าวต้ม เนื้อ เกี๊ยว เพิ่ม ได้ตัว โดยรวม โอเค ส่วนตัว วุ้นเส้น เย็นตาโฟ ทะเล วุ้นเส้น เยอะ เครื่อง ทะเล ปลาหมึก กุ้ง แมงกะพรุน ลูกชิ้น รสชาติ เย็นตาโฟ อร่อย กลมกล่อม ไม่ต้อง ปรุง เพิ่ม เส้น เส้น หนึบ พร้อม ลูกชิ้น รสชาติ อร่อย น้ำแข็งเปล่า แก้ว น้ำเปล่า โดยรวม โอเค'

# %%
cv.vocabulary_
# Out:
# {'ร้าน': 4630,
#  'ก๋วยเตี๋ยว': 509,
#  'อยู่': 6419,
#  'ฝั่ง': 3655,
#  'ตรงข้าม': 1908,
#  'นครนายก': 2746,
#  'สามารถ': 5689,
#  'หน้าร้าน': 6026,
#  'ประมาณ': 3407,
#  'เรีย': 8823,
#  'โอเพ่น': 9926,
#  'แอร์': 9733,
#  'ห้อง': 6332,
#  'ติดแอร์': 2055,
#  'การบริการ': 294,
#  'มาตรฐาน': 4022,
#  'อาหาร': 6933,
#  'เน้น': 7927,
#  'เป็น': 8042,
#  'ลูกชิ้น': 5136,
#  'อาหารตา': 7058,
#  'สั่ง': 5499,
#  'เส้นใหญ่': 9144,
#  'เพิ่ม': 8436,
#  'เกี๊ยว': 7237,
#  'น้ำจิ้ม': 3089,
#  'เต้าเจี้ยว': 7769,
#  'ด้วย': 1736,
#  'รสชาติ': 4215,
#  'กลมกล่อม': 120,
#  'คล้ายๆ': 1049,
#  'ข้าวต้ม': 757,
#  'เนื้อ': 7840,
#  'ได้ตัว': 10125,
#  'โดยรวม': 9781,
#  'โอเค': 9899,
#  'ส่วนตัว': 5876,
#  'วุ้นเส้น': 5257,
#  'เย็นตาโฟ': 8806,
#  'ทะเล': 2337,
#  'เยอะ': 8673,
#  'เครื่อง': 7373,
#  'ปลาหมึก': 3497,
#  'กุ้ง': 403,
#  'อร่อย': 6609,
#  'ไม่ต้อง': 10209,
#  'ปรุง': 3464,
#  'เส้น': 9118,
#  'หนึบ': 5938,
#  'พร้อม': 3745,
#  'น้ำแข็งเปล่า': 3179,
#  'แก้ว': 9330,
#  'น้ำเปล่า': 3166,
#  'ร้าน ก๋วยเตี๋ยว': 4646,
#  'ก๋วยเตี๋ยว อยู่': 528,
#  'อยู่ ฝั่ง': 6473,
#  'ฝั่ง ตรงข้าม': 3660,
#  'สามารถ หน้าร้าน': 5698,
#  'ประมาณ ร้าน': 3417,
#  'โอเพ่น แอร์': 9927,
#  'แอร์ ห้อง': 9740,
#  'อาหาร เน้น': 7023,
#  'เน้น เป็น': 7934,
#  'เป็น ก๋วยเตี๋ยว': 8059,
#  'ก๋วยเตี๋ยว ลูกชิ้น': 524,
#  'อาหารตา สั่ง': 7059,
#  'สั่ง สั่ง': 5573,
#  'สั่ง เส้นใหญ่': 5616,
#  'สั่ง น้ำจิ้ม': 5545,
#  'น้ำจิ้ม เต้าเจี้ยว': 3104,
#  'ด้วย รสชาติ': 1789,
#  'รสชาติ กลมกล่อม': 4217,
#  'โดยรวม โอเค': 9795,
#  'เยอะ เครื่อง': 8738,
#  'เครื่อง ทะเล': 7376,
#  'ปลาหมึก กุ้ง': 3500,
#  'เย็นตาโฟ อร่อย': 8809,
#  'อร่อย กลมกล่อม': 6612,
#  'กลมกล่อม ไม่ต้อง': 134,
#  'ไม่ต้อง ปรุง': 10213,
#  'ปรุง เพิ่ม': 3469,
#  'เส้น เส้น': 9139,
#  'รสชาติ อร่อย': 4290,
#  'ผู้ชาย': 3626,
#  'เข้าไป': 7357,
#  'นั่ง': 2812,
#  'แต่ง': 9404,
#  'โชว์': 9766,
#  'อย่างชัดเจน': 6591,
#  'เข้า': 7315,
#  'ไม่ค่อย': 10166,
#  'เหมาะ': 9164,
#  'เท่าไหร่': 7811,
#  'ชัดเจน': 1414,
#  'เนื่องจาก': 7835,
#  'ตำแหน่ง': 2045,
#  'โต๊ะ': 9809,
#  'พื้นที่': 3869,
#  'ลูกค้า': 5109,
#  'โล่ง': 9890,
#  'อึดอัด': 7110,
#  'ข้างๆ': 703,
#  'หลาย': 6163,
#  'ที่นั่ง': 2570,
#  'รู้สึก': 4568,
#  'สบายดี': 5338,
#  'ส่วน': 5830,
#  'หลัก': 6128,
#  'กลางๆ': 159,
#  'เข้าไป นั่ง': 7360,
#  'แต่ง ร้าน': 9405,
#  'เข้า ร้าน': 7319,
#  'ร้าน นั่ง': 4743,
#  'นั่ง ด้วย': 2824,
#  'ร้าน ชัดเจน': 4683,
#  'เนื่องจาก ร้าน': 7836,
#  'โล่ง นั่ง': 9891,
#  'โต๊ะ ข้างๆ': 9811,
#  'ส่วน อาหาร': 5861,
#  'อาหาร หลัก': 7000,
#  'รสชาติ กลางๆ': 4218,
#  'อาหาร อยู่': 7005,
#  'อยู่ เยอะ': 6518,
#  'เดินผ่าน': 7646,
#  'ทุกวัน': 2668,
#  'เอ๊ะ': 9308,
#  'หรือ': 6085,
#  'พึ่ง': 3865,
#  'เปิด': 7990,
#  'ง่าย': 1281,
#  'ครับ': 837,
#  'เดิน': 7615,
#  'สยาม': 5362,
#  'เข้ามา': 7340,
#  'เห็น': 9257,
#  'สีชมพู': 5766,
#  'ไม่เคย': 10292,
#  'เค้า': 7477,
#  'พอได้': 3817,
#  'ครั้งแรก': 1000,
#  'ติดใจ': 2056,
#  'แล้ว': 9558,
#  'อุดหนุน': 7149,
#  'ใหม่': 10049,
#  'พึ่ง เปิด': 3866,
#  'ง่าย ครับ': 1284,
#  'ครับ เดิน': 935,
#  'เห็น ร้าน': 9265,
#  'ไม่เคย ร้าน': 10298,
#  'ร้าน เค้า': 4882,
#  'ครับ แล้ว': 960,
#  'นะคะ': 2773,
#  'ทางผ่าน': 2452,
#  'เยี่ยม': 8774,
#  'ถ่ายรูป': 2303,
#  'ใหญ่โต': 10048,
#  'ข้างใน': 699,
#  'เครื่องดื่ม': 7387,
#  'ราคา': 4399,
#  'เทียบ': 7779,
#  'เหมาะกับ': 9168,
#  'ต้อง': 2140,
#  'ขอโทษ': 631,
#  'ห่วย': 6326,
#  'สปาเกตตี': 5340,
#  'กว่า': 200,
#  'แบรนด์': 9497,
#  'ทุกคน': 2659,
#  'อึ้ง': 7111,
#  'ทั้ง': 2367,
#  'แปลก': 9500,
#  'อีกแล้ว': 7108,
#  'ไปมา': 10153,
#  'ตั้งแต่': 2005,
#  'ร้าน นะคะ': 4742,
#  'นะคะ รสชาติ': 2780,
#  'รสชาติ ส่วน': 4282,
#  'ส่วน เครื่องดื่ม': 5863,
#  'เครื่องดื่ม ราคา': 7398,
#  'ราคา เทียบ': 4486,
#  'อาหาร ราคา': 6989,
#  'ทั้ง โต๊ะ': 2426,
#  'ราคา ด้วย': 4422,
#  'ไปมา แล้ว': 10154,
#  'แล้ว ตั้งแต่': 9577,
#  'วันนี้': 5189,
#  'มีโอกาส': 4067,
#  'กาแฟ': 318,
#  'แถวๆ': 9427,
#  'อารี': 6930,
#  'ได้ยิน': 10134,
#  'บ่อยๆ': 3327,
#  'บ่อย': 3325,
#  'ที่นี่': 2588,
#  'เรียกว่า': 8831,
#  'ระดับ': 4357,
#  'จนถึง': 1301,
#  'โอกาส': 9897,
#  'เสร็จ': 9072,
#  'มาหา': 4043,
#  'กินแถว': 391,
#  'พอดี': 3783,
#  'บรรยากาศ': 3183,
#  'อารมณ์': 6926,
#  'บ้าน': 3347,
#  'ต้นไม้': 2116,
#  'อย่างน้อย': 6595,
#  'เขียว': 7277,
#  'เล็ก': 8982,
#  'กลางเมือง': 158,
#  'ดีกว่า': 1681,
#  'ร้อน': 4598,
#  'ว่าง': 5260,
#  'ฟังเพลง': 3895,
#  'พักผ่อน': 3823,
#  'ได้ดี': 10122,
#  'ทีเดียว': 2518,
#  'จ่าย': 1391,
#  'พนักงาน': 3667,
#  'เพราะ': 8347,
#  'ถึงที่': 2250,
#  'เลือก': 8920,
#  'กระจก': 51,
#  'เอ้ย': 9305,
#  'ถนัด': 2226,
#  'หน่อย': 5953,
#  'ไม่นาน': 10222,
#  'เกิน': 7219,
#  'ไม่ทัน': 10220,
#  'ข้างหน้า': 697,
#  'โอ้ว': 9932,
#  'เล่น': 9021,
#  'ความ': 1056,
#  'น้ำตาล': 3121,
#  'เผลอ': 8309,
#  'ไม่ได้': 10322,
#  'เหลือ': 9230,
#  'หน้าตา': 6013,
#  'ผ่าน': 3630,
#  'เฮ้ย': 9312,
#  'รู้เรื่อง': 4585,
#  'เท่าที่': 7799,
#  'กลิ่น': 168,
#  'ไม่ธรรมดา': 10221,
#  'ถือว่า': 2254,
#  'รุ่น': 4555,
#  'เดียว': 7657,
#  'เมนู': 8506,
#  'อื่นๆ': 7130,
#  'ปั่น': 3519,
#  'เพื่อน': 8475,
#  'แหล่': 9715,
#  'ไม่แพ้': 10315,
#  'ครีม': 1013,
#  'หวาน': 6212,
#  'โกโก้': 9750,
#  'น้ำส้ม': 3158,
#  'เค้ก': 7448,
#  'ช็อกโกแลต': 1534,
#  'แจ่ม': 9368,
#  'สรุป': 5370,
#  'ก็คือ': 444,
#  'ก็ดี': 446,
#  'บริการ': 3228,
#  'เหอะ': 9243,
#  'ถ่าย': 2301,
#  'กล้อง': 194,
#  'เท่า': 7795,
#  'วันนี้ มีโอกาส': 5200,
#  'นั่ง กาแฟ': 2815,
#  'กาแฟ ร้าน': 331,
#  'กาแฟ ที่นี่': 325,
#  'ที่นี่ อร่อย': 2603,
#  'บรรยากาศ ร้าน': 3208,
#  'ร้าน แต่ง': 4947,
#  'อารมณ์ ประมาณ': 6927,
#  'อยู่ บ้าน': 6469,
#  'ต้นไม้ เยอะ': 2118,
#  'เดิน เข้า': 7631,
#  'ร้อน แก้ว': 4623,
#  'ได้ดี ทีเดียว': 10124,
#  'เสร็จ พนักงาน': 9075,
#  'โต๊ะ เพราะ': 9840,
#  'เพราะ ที่นี่': 8361,
#  'เลือก ที่นั่ง': 8931,
#  'หน่อย นั่ง': 5961,
#  'ร้อน อยู่': 4616,
#  'เล่น ด้วย': 9024,
#  'ด้วย ความ': 1751,
#  'ไม่ได้ ถ่ายรูป': 10334,
#  'ที่นี่ รสชาติ': 2598,
#  'รสชาติ กลิ่น': 4219,
#  'ถือว่า เป็น': 2279,
#  'เมนู อื่นๆ': 8591,
#  'ครีม หวาน': 1018,
#  'ส่วน เพื่อน': 5869,
#  'เพื่อน สั่ง': 8485,
#  'บรรยากาศ ก็ดี': 3185,
#  'บริการ ก็ดี': 3229,
#  'กาแฟ อร่อย': 337,
#  'อร่อย ราคา': 6695,
#  'ไม่ได้ อยู่': 10349,
#  'อยู่ ตรงข้าม': 6448,
#  'สารภาพ': 5711,
#  'ซื้อ': 1619,
#  'บังเอิญ': 3288,
#  'เจอกัน': 7517,
#  'คนละ': 816,
#  'กล่อง': 189,
#  'น้อง': 3056,
#  'ใจดี': 9951,
#  'แบ่ง': 9498,
#  'หนึ่ง': 5941,
#  'ชิ้น': 1476,
#  'ถ้วน': 2310,
#  'เกือบ': 7245,
#  'ชั่วโมง': 1418,
#  'หลัง': 6130,
#  'เก้าอี้': 7267,
#  'สะดวก': 5431,
#  'สำหรับ': 5720,
#  'ต่อไป': 2090,
#  'มาถึง': 4030,
#  'โดนัท': 9773,
#  'เสียดาย': 9101,
#  'ทิ้ง': 2512,
#  'อุ่น': 7154,
#  'น่าจะ': 3018,
#  'แป้ง': 9513,
#  'นิ่ม': 2940,
#  'ยี่ห้อ': 4140,
#  'ใกล้เคียง': 9946,
#  'เดียวกัน': 7679,
#  'ทำให้': 2486,
#  'เวลา': 9038,
#  'ออกมา': 6826,
#  'ยิ่ง': 4127,
#  'เคลือบ': 7426,
#  'ซึ่ง': 1598,
#  'ขึ้นไป': 673,
#  'หวัง': 6211,
#  'นานๆ': 2898,
#  'อย่า': 6539,
#  'ความนิยม': 1086,
#  'ยังไง': 4114,
#  'ลดลง': 5046,
#  'แล้ว เค้า': 9636,
#  'หนึ่ง ชิ้น': 5943,
#  'เพราะ สั่ง': 8376,
#  'สั่ง ทั้ง': 5535,
#  'หลัง ร้าน': 6131,
#  'ร้าน ที่นั่ง': 4730,
#  'ครับ เป็น': 942,
#  'เป็น โต๊ะ': 8249,
#  'โต๊ะ เก้าอี้': 9835,
#  'ไม่ค่อย นั่ง': 10172,
#  'ร้าน อยู่': 4855,
#  'แล้ว ไม่ค่อย': 9666,
#  'เสร็จ ใหม่': 9080,
#  'หรือ เพิ่ม': 6111,
#  'น่าจะ ดีกว่า': 3020,
#  'เนื้อ แป้ง': 7899,
#  'แป้ง นิ่ม': 9516,
#  'ทำให้ เวลา': 2502,
#  'กว่า หวาน': 218,
#  'เพราะ แป้ง': 8403,
#  'หวาน แป้ง': 6272,
#  'ง่าย กว่า': 1282,
#  'ยิ่ง ทำให้': 4129,
#  'อยู่ ซึ่ง': 6437,
#  'หวาน พอดี': 6236,
#  'อยู่ แล้ว': 6528,
#  'แล้ว หวาน': 9620,
#  'ยังไง ต้อง': 4115,
#  'วันก่อน': 5181,
#  'หลังจาก': 6134,
#  'ห่าง': 6329,
#  'เดือน': 7687,
#  'เดินทาง': 7641,
#  'รถไฟฟ้า': 4199,
#  'ชั้น': 1420,
#  'เจ้าของร้าน': 7533,
#  'น่ารัก': 3036,
#  'แนะนำ': 9439,
#  'แต่งหน้า': 9407,
#  'แล้วก็': 9675,
#  'ผิดหวัง': 3611,
#  'จริงๆ': 1313,
#  'นุ่ม': 2961,
#  'แห้ง': 9721,
#  'กำลัง': 356,
#  'แครอท': 9362,
#  'สุขภาพ': 5781,
#  'ไม่มี': 10232,
#  'ลิ่ม': 5100,
#  'ชุ่ม': 1529,
#  'เช่นกัน': 7584,
#  'อย่าง': 6547,
#  'ประทับใจ': 3395,
#  'กร้าน': 108,
#  'กลับ': 136,
#  'ขออนุญาต': 628,
#  'เว็บ': 9062,
#  'ประมาณ เดือน': 3421,
#  'แล้ว ร้าน': 9604,
#  'อยู่ ชั้น': 6430,
#  'ด้วย น่ารัก': 1775,
#  'แนะนำ เป็น': 9462,
#  'เป็น เค้ก': 8205,
#  'ด้วย ครีม': 1750,
#  'เมนู แนะนำ': 8617,
#  'แนะนำ ร้าน': 9452,
#  'ร้าน ซื้อ': 4690,
#  'แล้วก็ ผิดหวัง': 9679,
#  'ผิดหวัง จริงๆ': 3613,
#  'จริงๆ เพราะ': 1334,
#  'เพราะ เนื้อ': 8391,
#  'เนื้อ เค้ก': 7884,
#  'เค้ก นุ่ม': 7458,
#  'นุ่ม แห้ง': 3007,
#  'หวาน กำลัง': 6218,
#  'กำลัง พอดี': 357,
#  'พอดี ราคา': 3786,
#  'ด้วย ส่วน': 1800,
#  'หน่อย แล้ว': 5986,
#  'ไม่ค่อย หวาน': 10185,
#  'สั่ง อย่าง': 5586,
#  'นะคะ เพราะ': 2796,
#  'อะไร': 6840,
#  'ใกล้': 9936,
#  'บ้าง': 3331,
#  'ร้านอาหาร': 5004,
#  'สไตล์': 5818,
#  'จิ้ม': 1372,
#  'จุ่ม': 1390,
#  'ปิ้ง': 3548,
#  'ย่าง': 4152,
#  'ชื่อ': 1512,
#  'เด็ด': 7696,
#  'แน่นอน': 9480,
#  'บริเวณ': 3263,
#  'มาจาก': 4018,
#  'ไม่ว่า': 10281,
#  'ก็ตาม': 449,
#  'เลี้ยว': 8911,
#  'สิริ': 5763,
#  'ที่จะ': 2558,
#  'มุ่งหน้า': 4089,
#  'ร้อย': 4627,
#  'เมตร': 8503,
#  'เชิง': 7562,
#  'สะพาน': 5443,
#  'ข้าม': 705,
#  'ซ้ายมือ': 1644,
#  'ด้านล่าง': 1864,
#  'ไม่งั้น': 10203,
#  'ช่วง': 1542,
#  'เย็น': 8780,
#  'กระทะ': 64,
#  'ทั่วไป': 2359,
#  'เพียงแต่': 8465,
#  'ไม่ใช่': 10317,
#  'บุฟเฟ่ต์': 3317,
#  'แออัด': 9747,
#  'จัดวาง': 1350,
#  'สบาย': 5315,
#  'อากาศ': 6896,
#  'ถ่ายเท': 2309,
#  'ถึงแม้ว่า': 2252,
#  'ควัน': 1055,
#  'รบกวน': 4201,
#  'แต่อย่างใด': 9422,
#  'นอกจาก': 2756,
#  'แสงไฟ': 9703,
#  'อาจจะ': 6903,
#  'น้อย': 3064,
#  'ลำบาก': 5091,
#  'หรือยัง': 6116,
#  'เนี่ย': 7832,
#  'ที่สำคัญ': 2635,
#  'เพลง': 8416,
#  'เหมือนกัน': 9203,
#  'เข้ากับ': 7334,
#  'เหรอ': 9226,
#  'ด้วยกัน': 1843,
#  'ได้แก่': 10147,
#  'พร้อมกับ': 3757,
#  'หม้อดิน': 6076,
#  'ต่าง': 2092,
#  'ลักษณะ': 5076,
#  'กับแกล้ม': 281,
#  'เหมาะสำหรับ': 9176,
#  'เบียร์': 7949,
#  'เลิกงาน': 8894,
#  'โฆษณา': 9761,
#  'วุ้น': 5255,
#  'ครั้งนี้': 991,
#  'แล้วกัน': 9673,
#  'ตามที่': 2023,
#  'อุปกรณ์': 7153,
#  'ได้มา': 10129,
#  'เพียง': 8459,
#  'ขนาด': 571,
#  'ใหญ่': 9994,
#  'ก่อน': 466,
#  'ช่วย': 1560,
#  'ให้อาหาร': 10081,
#  'มื้อ': 4076,
#  'ความชอบ': 1082,
#  'เนื้อสัตว์': 7912,
#  'เนื้อวัว': 7909,
#  'เนื้อหมู': 7914,
#  'ไม่ผิด': 10229,
#  'คุณภาพ': 1180,
#  'ค่อนข้าง': 1229,
#  'เลยทีเดียว': 8879,
#  'ที่ทาง': 2567,
#  'แทรก': 9434,
#  'น่อง': 3014,
#  'คนที': 809,
#  'วิธีการ': 5249,
#  'ง่ายๆ': 1292,
#  'ละลาย': 5066,
#  'แล้วแต่': 9692,
#  'แกล้ม': 9328,
#  'เหาะ': 9245,
#  'ช่วยกัน': 1563,
#  'คุ้มค่า': 1216,
#  'เมื่อ': 8645,
#  'ครับผม': 976,
#  'ใกล้ บ้าน': 9939,
#  'บ้าง ครับ': 3332,
#  'ครับ ร้าน': 900,
#  'เป็น ร้านอาหาร': 8153,
#  'ร้านอาหาร สไตล์': 5016,
#  'จิ้ม จุ่ม': 1374,
#  'ปิ้ง ย่าง': 3553,
#  'ชื่อ ร้าน': 1513,
#  'ร้าน แล้ว': 4956,
#  'แล้ว น่าจะ': 9588,
#  'น่าจะ ร้าน': 3023,
#  'ร้าน เนื้อ': 4902,
#  'เนื้อ ต้อง': 7857,
#  'แน่นอน ร้าน': 9483,
#  'อยู่ บริเวณ': 6466,
#  'เลี้ยว เข้า': 8912,
#  'สะพาน ข้าม': 5444,
#  'อยู่ ซ้ายมือ': 6438,
#  'ซ้ายมือ ครับ': 1646,
#  'ข้าม สะพาน': 706,
#  'ร้าน ครับ': 4669,
#  'ร้าน เปิด': 4907,
#  'เปิด ช่วง': 7993,
#  'ช่วง เย็น': 1553,
#  'ครับ บรรยากาศ': 881,
#  'คล้ายๆ ร้าน': 1050,
#  'ร้าน กระทะ': 4632,
#  'อากาศ ถ่ายเท': 6897,
#  'ไม่มี กลิ่น': 10234,
#  'นั่ง โต๊ะ': 2868,
#  'อาจจะ น้อย': 6907,
#  'ย่าง เนื้อ': 4174,
#  'ลำบาก หน่อย': 5092,
#  'หน่อย ต้อง': 5958,
#  'ที่สำคัญ ร้าน': 2637,
#  'เปิด เพลง': 8012,
#  'เพลง เพราะ': 8419,
#  'เพราะ เป็น': 8393,
#  'เพลง สบาย': 8417,
#  'สไตล์ ร้าน': 5825,
#  'อยู่ เลือก': 6521,
#  'ต่าง กร้าน': 2093,
#  'เพราะ ร้าน': 8373,
#  'ร้าน เป็น': 4909,
#  'เป็น ลักษณะ': 8154,
#  'กระทะ ร้อน': 65,
#  'ร้อน ครับ': 4601,
#  'ครับ ส่วน': 909,
#  'ส่วน เมนู': 5870,
#  'อื่นๆ เป็น': 7142,
#  'เป็น สไตล์': 8169,
#  'หลัง เลิกงาน': 6132,
#  'จริงๆ ร้าน': 1323,
#  'เบียร์ วุ้น': 7951,
#  'ส่วน ปิ้ง': 5848,
#  'แล้วกัน ครับ': 9674,
#  'ย่าง เป็น': 4176,
#  'ขนาด ใหญ่': 583,
#  'ช่วย เพิ่ม': 1561,
#  'เพิ่ม ความ': 8438,
#  'น้ำจิ้ม ร้าน': 3097,
#  'น้ำจิ้ม น้ำจิ้ม': 3091,
#  'ย่าง ครับ': 4156,
#  'ครับ ซึ่ง': 861,
#  'ซึ่ง สามารถ': 1611,
#  'สามารถ เลือก': 5702,
#  'เนื้อวัว เนื้อหมู': 7910,
#  'เนื้อหมู เนื้อวัว': 7917,
#  'เลือก หลาย': 8952,
#  'หลาย ส่วน': 6180,
#  'ที่ทาง ร้าน': 2568,
#  'ร้าน แนะนำ': 4948,
#  'เป็น ส่วน': 8170,
#  'ส่วน เนื้อ': 5866,
#  'เนื้อ นุ่ม': 7860,
#  'เนื้อ ส่วน': 7876,
#  'ส่วน อื่นๆ': 5862,
#  'เนื้อ น่อง': 7861,
#  'ครับ สำหรับ': 907,
#  'สำหรับ คนที': 5724,
#  'ร้อน เนื้อ': 4618,
#  'เนื้อ ย่าง': 7865,
#  'อร่อย เหาะ': 6786,
#  'เมนู ไม่ค่อย': 8627,
#  'ไม่ค่อย สั่ง': 10183,
#  'กลางๆ ครับ': 160,
#  'ครับ ต้อง': 865,
#  'หน่อย สำหรับ': 5971,
#  'สำหรับ เมนู': 5753,
#  'โดยรวม ถือว่า': 9783,
#  'ถือว่า คุ้มค่า': 2258,
#  'เมื่อ เทียบ': 8653,
#  'เทียบ คุณภาพ': 7780,
#  'คุณภาพ ราคา': 1185,
#  'ราคา ครับ': 4412,
#  'กลับมา': 142,
#  'ไต้หวัน': 10151,
#  'ทันที': 2347,
#  'ไข่มุก': 10102,
#  'เหมือน': 9181,
#  'เหนียว': 9149,
#  'น้ำแข็ง': 3171,
#  'นิดเดียว': 2923,
#  'เจ้า': 7528,
#  'ตลาด': 1936,
#  'เหนียว นุ่ม': 9152,
#  'นุ่ม หวาน': 2990,
#  'ราคา แก้ว': 4505,
#  'กว่า เจ้า': 226,
#  'รสชาติ จริงๆ': 4237,
#  'ที่มา': 2621,
#  'แต่ว่า': 9421,
#  'เครป': 7368,
#  'ขนมปัง': 550,
#  'กรอบ': 4,
#  'ไอติม': 10387,
#  'เข้ากันได้': 7332,
#  'ลงตัว': 5035,
#  'เพราะว่า': 8413,
#  'เลี่ยน': 8903,
#  'แย่ง': 9552,
#  'เยอะ ประมาณ': 8706,
#  'ประมาณ เกือบ': 3420,
#  'เครป อร่อย': 7370,
#  'อร่อย อร่อย': 6731,
#  'อร่อย ขนมปัง': 6623,
#  'ขนมปัง กรอบ': 551,
#  'กรอบ ร้อน': 23,
#  'แนะนำ นะคะ': 9448,
#  'ต้อง เยอะ': 2202,
#  'หลาย อย่าง': 6184,
#  'ด้านบน': 1862,
#  'ไม่อร่อย': 10285,
#  'น้ำผลไม้': 3131,
#  'มะพร้าว': 3956,
#  'ชื่นใจ': 1511,
#  'แผ่น': 9534,
#  'ห้องอาหาร': 6344,
#  'อาหารคาว': 7051,
#  'ขนมหวาน': 565,
#  'พนักงานบริการ': 3705,
#  'เรื่อง': 8850,
#  'การปรับปรุง': 308,
#  'ข้างล่าง': 696,
#  'สวยม': 5420,
#  'พระอาทิตย์': 3719,
#  'อาทิ': 6919,
#  'เมนู เครื่องดื่ม': 8593,
#  'อาหาร อร่อย': 7007,
#  'อร่อย ทั้ง': 6655,
#  'ทั้ง อาหารคาว': 2408,
#  'อาจจะ เพราะ': 6911,
#  'ด้วย นะคะ': 1773,
#  'วันอาทิตย์': 5232,
#  'ทานอาหาร': 2467,
#  'ที่อื่น': 2653,
#  'ลงทุน': 5039,
#  'ขับรถ': 633,
#  'เพื่อ': 8469,
#  'อดทน': 6365,
#  'สุดยอด': 5787,
#  'ดวงใจ': 1666,
#  'กลับบ้าน': 139,
#  'แฮปปี้': 9748,
#  'เหมือนเดิม': 9217,
#  'แล้ว ต้อง': 9579,
#  'ที่นี่ เยอะ': 2611,
#  'เยอะ ต้อง': 8692,
#  'วันนี้ ได้มา': 5227,
#  'แล้ว รสชาติ': 9600,
#  'รสชาติ เหมือนเดิม': 4317,
#  'ที่อยู่': 2650,
#  'ริมแม่น้ำ': 4550,
#  'เจ้าพระยา': 7546,
#  'แม่น้ำ': 9547,
#  'ซ้าย': 1642,
#  'โรงแรม': 9881,
#  'เรียน': 8838,
#  'ทางขวา': 2447,
#  'อรุณ': 6608,
#  'สวยงาม': 5417,
#  'เท่านั้น': 7803,
#  'ไม่พอ': 10230,
#  'วันนั้น': 5187,
#  'ฝรั่ง': 3652,
#  'นิดๆ': 2924,
#  'เช่น': 7578,
#  'เขียวหวาน': 7278,
#  'แกงเขียวหวาน': 9325,
#  'สมุนไพร': 5357,
#  'หลายชนิด': 6200,
#  'ผู้จัดการ': 3625,
#  'ตั้งอยู่': 1989,
#  'ทัวร์': 2354,
#  'เป็นประจำ': 8278,
#  'ทำไม': 2508,
#  'แบบนี้': 9489,
#  'คนไทย': 831,
#  'ความตั้งใจ': 1084,
#  'โปรโมท': 9863,
#  'มากขึ้น': 4006,
#  'เก่า': 7261,
#  'ร้าน ร้าน': 4809,
#  'เป็น ร้าน': 8151,
#  'ร้าน ที่อยู่': 4734,
#  'ริมแม่น้ำ เจ้าพระยา': 4551,
#  'เนื่องจาก อยู่': 7837,
#  'ร้าน เห็น': 4943,
#  'ไม่มี อะไร': 10255,
#  'อยู่ บ่อยๆ': 6467,
#  'ครับ อาหาร': 926,
#  'อาหาร ที่นี่': 6961,
#  'ที่นี่ เป็น': 2608,
#  'เป็น อาหาร': 8194,
#  'เหมาะ ที่จะ': 9165,
#  'เป็น แป้ง': 8241,
#  'แป้ง กรอบ': 9514,
#  'กรอบ ด้วย': 13,
#  'เป็น ชิ้น': 8088,
#  'อร่อย ครับ': 6628,
#  'ร้าน กว่า': 4635,
#  'กว่า ร้าน': 211,
#  'ร้าน ลูกค้า': 4812,
#  'อยู่ เหมือนกัน': 6525,
#  'กว่า เป็น': 229,
#  'ครับ โดยรวม': 962,
#  'อย่าง เดียว': 6581,
#  'เดียว ครับ': 7659,
#  'หนึ่ง ร้าน': 5944,
#  'ร้าน เก่า': 4870,
#  'หน่อย ครับ': 5955,
#  'ระหว่าง': 4372,
#  'เหมือนว่า': 9215,
#  'เป็นอัน': 8293,
#  'นุ่มนวล': 3010,
#  'ขึ้น': 651,
#  'ละไม': 5074,
#  'เกินไป': 7226,
#  'มลิ้น': 3930,
#  'อื่น': 7113,
#  'หลอด': 6127,
#  'เสียเวลา': 9111,
#  'เทียบ ร้าน': 7784,
#  'ร้าน อื่นๆ': 4866,
#  'เท่านั้น ครับ': 7804,
#  'เยอะ ทำให้': 8694,
#  'เวลา แล้ว': 9052,
#  'ขึ้น เยอะ': 663,
#  'เข้า แล้ว': 7325,
#  'ละไม หวาน': 5075,
#  'หวาน เกินไป': 6255,
#  'เข้าไป แล้ว': 7366,
#  'เหมือน อยู่': 9196,
#  'เลยทีเดียว ครับ': 8880,
#  'เจ้า อื่น': 7530,
#  'เค้า ต้อง': 7482,
#  'ด้วย ต้อง': 1766,
#  'มากมาย': 4007,
#  'ดีเยี่ยม': 1701,
#  'หน้า': 5994,
#  'เต็มๆ': 7759,
#  'ให้คะแนน': 10071,
#  'พุ่ง': 3878,
#  'ปรี๊ด': 3463,
#  'ทะลุ': 2336,
#  'ตกไป': 1901,
#  'ป้าย': 3573,
#  'ต่างๆ': 2100,
#  'ทำได้': 2505,
#  'ไม่รู้': 10271,
#  'บริษัท': 3262,
#  'นะเนี่ย': 2805,
#  'ร้าน เครื่องดื่ม': 4880,
#  'เครื่องดื่ม เลือก': 7411,
#  'เลือก มากมาย': 8940,
#  'ซื้อ ด้วย': 1625,
#  'ปกติ': 3365,
#  'กินที่': 384,
#  'สาขา': 5649,
#  'เท่านี้': 7808,
#  'พระราม': 3716,
#  'รู้จัก': 4564,
#  'เกรด': 7194,
#  'สะใจ': 5466,
#  'แบบผม': 9496,
#  'กรุบ': 101,
#  'ตุ๋น': 2075,
#  'เนื้อสด': 7911,
#  'พริก': 3722,
#  'ว้าว': 5268,
#  'คราวหน้า': 1009,
#  'หม้อ': 6070,
#  'ร้าน คุณภาพ': 4676,
#  'กร้าน ครับ': 109,
#  'ครับ ปกติ': 884,
#  'กินที่ สาขา': 387,
#  'สาขา สยาม': 5662,
#  'สาขา พระราม': 5657,
#  'ก๋วยเตี๋ยว เนื้อ': 530,
#  'ต้อง รู้จัก': 2177,
#  'ทั้ง เนื้อ': 2414,
#  'ตุ๋น รสชาติ': 2078,
#  'รสชาติ หวาน': 4287,
#  'หวาน นุ่ม': 6232,
#  'เป็น ต้อง': 8104,
#  'ต้อง เค้า': 2193,
#  'ก่อน ครับ': 471,
#  'ครับ อร่อย': 922,
#  'คราวหน้า ต้อง': 1010,
#  'ส้มตำ': 5906,
#  'ข้าวโพด': 793,
#  'ไข่เค็ม': 10104,
#  'เสิร์ฟ': 9084,
#  'ตกใจ': 1899,
#  'อีสาน': 7109,
#  'จริง': 1304,
#  'ได้ยิน ชื่อ': 10135,
#  'ร้าน ผ่าน': 4776,
#  'หน่อย สั่ง': 5970,
#  'สั่ง ส้มตำ': 5577,
#  'ข้าวโพด ไข่เค็ม': 796,
#  'ถือว่า เยอะ': 2280,
#  'เยอะ เกิน': 8736,
#  'เกิน ราคา': 7223,
#  'ราคา รสชาติ': 4452,
#  'สำหรับ อาหาร': 5746,
#  'อาหาร อีสาน': 7013,
#  'อาหาร เสิร์ฟ': 7034,
#  'หลากหลาย': 6142,
#  'ชั่น': 1416,
#  'กลาง': 151,
#  'พูดถึง': 3882,
#  'สมราคา': 5346,
#  'ทาร์': 2471,
#  'มะนาว': 3950,
#  'ที่สุด': 2639,
#  'เป็นเรื่อง': 8295,
#  'ที่จอดรถ': 2533,
#  'อาหาร หลากหลาย': 7001,
#  'ด้วย ราคา': 1790,
#  'ราคา อยู่': 4470,
#  'อยู่ ระดับ': 6479,
#  'คุณภาพ อาหาร': 1189,
#  'ด้วย อร่อย': 1807,
#  'อร่อย สุดยอด': 6715,
#  'อย่าง อื่น': 6578,
#  'อื่น อร่อย': 7121,
#  'ร้าน ที่จอดรถ': 4727,
#  'ชนะเลิศ': 1402,
#  'คร่า': 1028,
#  'งดงาม': 1277,
#  'ปริ่ม': 3462,
#  'ภูเก็ต': 3922,
#  'อลังการ': 6816,
#  'เป๊ะ': 8308,
#  'แหนม': 9706,
#  'เนือง': 7834,
#  'แซ่บ': 9385,
#  'กระดูก': 56,
#  'เพลิน': 8423,
#  'เอ้า': 9307,
#  'ไปดู': 10152,
#  'เดี๋ยว': 7683,
#  'หาว่า': 6311,
#  'ที่นั่ง สบาย': 2580,
#  'บ้าน ร้าน': 3352,
#  'ร้าน แบบนี้': 4951,
#  'อาหาร รสชาติ': 6988,
#  'รสชาติ เยี่ยม': 4313,
#  'แหนม เนือง': 9707,
#  'แซ่บ กระดูก': 9386,
#  'บรรยากาศ รสชาติ': 3204,
#  'รสชาติ อาหาร': 4294,
#  'ตอนแรก': 1961,
#  'คาดหวัง': 1150,
#  'ดีงาม': 1687,
#  'ถนนใหญ่': 2225,
#  'กลัว': 149,
#  'บ้านไร่': 3363,
#  'ถึงแม้': 2251,
#  'ไม่เข้าใจ': 10291,
#  'ต้มยำ': 2122,
#  'เผ็ด': 8314,
#  'อยากได้': 6417,
#  'ครั้งหน้า': 996,
#  'เฉพาะ': 7552,
#  'นอกจากนี้': 2765,
#  'คุณภาพดี': 1191,
#  'ฟู้ด': 3900,
#  'ของกิน': 599,
#  'ของหวาน': 609,
#  'ขนมไทย': 570,
#  'ผลไม้': 3587,
#  'ไอศครีม': 10399,
#  'น้ำอัดลม': 3162,
#  'น้ำหวาน': 3161,
#  'ตามสบาย': 2033,
#  'สะอาด': 5451,
#  'ร้าน บุฟเฟ่ต์': 4760,
#  'ไม่ได้ คาดหวัง': 10327,
#  'คาดหวัง อะไร': 1151,
#  'อะไร ครับ': 6842,
#  'ครับ เนื่องจาก': 937,
#  'เนื่องจาก เป็น': 7838,
#  'ร้าน ไม่มี': 4984,
#  'ต้อง ใหม่': 2214,
#  'คุ้มค่า ครับ': 1217,
#  'อยู่ ถนนใหญ่': 6456,
#  'ร้าน เดียว': 4894,
#  'ข้างๆ ร้าน': 704,
#  'ร้าน แอร์': 4959,
#  'แอร์ นั่ง': 9736,
#  'ที่จอดรถ เยอะ': 2556,
#  'เยอะ ครับ': 8682,
#  'ครับ ไม่ต้อง': 970,
#  'ไม่ต้อง กลัว': 10210,
#  'พนักงาน น่ารัก': 3675,
#  'น่ารัก บริการ': 3043,
#  'ครับ รสชาติ': 895,
#  'รสชาติ เผ็ด': 4310,
#  'เผ็ด เกินไป': 8331,
#  'ค่อนข้าง ครับ': 1232,
#  'ครั้งหน้า สั่ง': 998,
#  'ครับ นอกจากนี้': 876,
#  'เนื้อ ทั้ง': 7858,
#  'ทั้ง เนื้อวัว': 2415,
#  'เทียบ ราคา': 7783,
#  'เสิร์ฟ เป็น': 9089,
#  'ชิ้น ใหญ่': 1504,
#  'จริงๆ ครับ': 1314,
#  'ของกิน เล่น': 601,
#  'เล่น อื่นๆ': 9027,
#  'รสชาติ ราคา': 4276,
#  'ราคา บรรยากาศ': 4438,
#  'บรรยากาศ บริการ': 3201,
#  'บริการ สะอาด': 3252,
#  'ต้นตำรับ': 2114,
#  'ข้างนอก': 692,
#  'ตรงกลาง': 1906,
#  'ภายใน': 3914,
#  'ตกแต่ง': 1879,
#  'ประดับ': 3389,
#  'เพียบ': 8466,
#  'เรื่อย': 8860,
#  'ถึงใจ': 2253,
#  'เบอร์': 7943,
#  'เนียน': 7829,
#  'บางคน': 3297,
#  'เปล่าๆ': 7986,
#  'เค็ม': 7437,
#  'นิดนึง': 2906,
#  'คนเดียว': 821,
#  'แน่ๆ': 9487,
#  'ถูกใจ': 2292,
#  'กำลังดี': 362,
#  'นี่แหละ': 2946,
#  'หิ้ว': 6320,
#  'ร้าน เค้ก': 4881,
#  'ร้านอาหาร ร้าน': 5014,
#  'อยู่ ตรงกลาง': 6447,
#  'หน่อย เป็น': 5980,
#  'ร้าน เล็ก': 4933,
#  'เล็ก ใหญ่': 9014,
#  'ใหญ่ ที่นั่ง': 10010,
#  'ที่นั่ง ทั้ง': 2573,
#  'ประมาณ โต๊ะ': 3425,
#  'ภายใน ร้าน': 3915,
#  'ร้าน น่ารัก': 4750,
#  'น่ารัก ตกแต่ง': 3039,
#  'เล็ก น้อย': 8994,
#  ...}

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
cv = TfidfVectorizer(tokenizer=lambda x:x.split(),ngram_range = (1,2), stop_words =["ฉัน","ผม"],
                     min_df=10,max_df=0.9,norm=None,
                     use_idf=False,smooth_idf=False)
cv.fit(train_clean_join)
X = cv.transform(train_clean_join).toarray()
y = df_train[1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
len(cv.vocabulary_)
# Out:
# 10411

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(X_train)
X_train_norm =  scaler.transform(X_train)
X_test_norm = scaler.transform(X_test)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score
clf = MultinomialNB()
scores = cross_val_score(clf,X_train,y_train, cv=10)
scores.mean()
# Out:
# 0.49505076095605327

# %%
clf = MultinomialNB()
clf.fit(X_train,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
y_predict = clf.predict(X_test)
print("Test accuracy : "+str(sum(y_test == y_predict)/len(y_test)*100))
# Out:
# Test accuracy : 50.57528764382191
